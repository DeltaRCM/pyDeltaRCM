# %%
import pyDeltaRCM
import foreset
#import ninety
import matplotlib.pyplot as plt

# %%
fjord = foreset.ReservoirModel(input_file='foreset.yaml')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 fjord = foreset.ReservoirModel(input_file='foreset.yaml')
#
# File ~/Downloads/pydeltarcm testing/pyDeltaRCM/foreset.py:20, in ReservoirModel.__init__(self, input_file, **kwargs)
#      18 def __init__(self, input_file, **kwargs):
#      19     # inherit from base model
# ---> 20     super().__init__(input_file, **kwargs)
#      22     # hook_after_create_domain is called here
#      23
#      24     # overwrite the initial data with this new basin shape
#      25     self.output_data()
#
# File ~/Downloads/pydeltarcm testing/pyDeltaRCM/pyDeltaRCM/model.py:136, in DeltaModel.__init__(self, input_file, defer_output, **kwargs)
#     134 if not defer_output:
#     135     self.hook_init_output_file()
# --> 136     self.init_output_file()
#     138     # record initial conditions
# ...

# %%
for _ in range(0, 5):
    fjord.update()

fjord.finalize()
# Out:
# Time: 26666.7; timestep: 1
# Time: 53333.3; timestep: 2
# Time: 80000.0; timestep: 3
# Time: 106666.7; timestep: 4
# Time: 133333.3; timestep: 5

# %%
fig, ax = plt.subplots()
ax.imshow(fjord.bed_elevation, cmap='viridis', origin='lower')
plt.show()
